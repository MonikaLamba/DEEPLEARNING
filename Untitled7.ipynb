# %% [markdown]
# <a href="https://colab.research.google.com/github/MonikaLamba/DEEPLEARNING/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gg1')
# Out:
# Mounted at /content/gg1

# %%
mydata = pd.read_csv('/content/gg1/MyDrive/10886_colab.csv')
mydata.head()
# Out:
#       SCN4A  13CDNA73       VCL        FS  ...  I_1100357     HBXAP    MAP4K4  GRADE
# 0  0.547133  0.632416  0.626759  0.500672  ...   0.700940  0.500389  0.560427      3
# 1  0.485898  0.655476  0.522190  0.492913  ...   0.533357  0.468432  0.411811      3
# 2  0.455341  0.594054  0.489674  0.423112  ...   0.517298  0.439819  0.391147      3
# 3  0.466215  0.585794  0.487378  0.485372  ...   0.472647  0.434332  0.463863      3
# 4  0.441978  0.590871  0.453596  0.458852  ...   0.497925  0.446266  0.328354      2
#
# [5 rows x 16381 columns]

# %%
print(mydata.keys())
# Out:
# Index(['SCN4A', '13CDNA73', 'VCL', 'FS', 'I_1000682', 'AMSH', 'PRKCL2',
#        'I_1100727', 'NM_014294.2', 'NM_020150.3',
#        ...
#        'FLJ13659', 'DIRC2', 'I_1109479', 'MYF6', 'I_965593', 'SLC12A6',
#        'I_1100357', 'HBXAP', 'MAP4K4', 'GRADE'],
#       dtype='object', length=16381)

# %%
type(mydata)
# Out:
# pandas.core.frame.DataFrame

# %%
mydata.describe()
# Out:
#            SCN4A   13CDNA73        VCL  ...      HBXAP     MAP4K4      GRADE
# count  74.000000  74.000000  74.000000  ...  74.000000  74.000000  74.000000
# mean    0.483533   0.632970   0.508669  ...   0.457919   0.423377   2.472973
# std     0.044384   0.065176   0.054174  ...   0.049455   0.054418   0.666682
# min     0.276682   0.391913   0.405915  ...   0.183526   0.289399   1.000000
# 25%     0.460250   0.590944   0.473648  ...   0.436499   0.387744   2.000000
# 50%     0.486422   0.640573   0.499253  ...   0.456517   0.420061   3.000000
# 75%     0.510377   0.676855   0.535914  ...   0.486812   0.454318   3.000000
# max     0.569545   0.763431   0.663404  ...   0.552417   0.594545   3.000000
#
# [8 rows x 16381 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(mydata["GRADE"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(mydata["SCN4A"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,15))
sns.heatmap(mydata)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(30,30))

mydata = pd.read_csv('/content/gg1/MyDrive/10886_colab.csv')
sns.heatmap(mydata.corr(), annot=True, cmap="hot", linewidths = 3)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(30,30))
mydata = pd.read_csv('/content/gg1/MyDrive/10886_colab.csv')

X = mydata.drop(["GRADE"], axis=1)
Y = mydata["GRADE"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20, random_state=0)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
#        SCN4A  13CDNA73       VCL  ...  I_1100357     HBXAP    MAP4K4
# 66  0.526310  0.588947  0.553830  ...   0.549609  0.492149  0.450785
# 27  0.478348  0.648072  0.550106  ...   0.532123  0.410849  0.400319
# 48  0.505895  0.540442  0.519620  ...   0.578685  0.463312  0.443956
# 57  0.417555  0.755222  0.423298  ...   0.564965  0.448665  0.312425
# 53  0.478902  0.706013  0.482694  ...   0.590140  0.478180  0.372178
# 6   0.556912  0.669639  0.606822  ...   0.680983  0.531096  0.475632
# 49  0.492444  0.666009  0.506767  ...   0.486692  0.483535  0.468817
# 69  0.535936  0.683016  0.540776  ...   0.662481  0.477863  0.413773
# 4   0.441978  0.590871  0.453596  ...   0.497925  0.446266  0.328354
# 55  0.494150  0.624182  0.476529  ...   0.567489  0.469982  0.415169
# 59  0.550723  0.681143  0.546995  ...   0.560141  0.466675  0.445876
# 2   0.455341  0.594054  0.489674  ...   0.517298  0.439819  0.391147
# 73  0.472026  0.620055  0.480536  ...   0.487839  0.443704  0.392964
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)
X_train
# Out:
# array([[ 1.06139216, -0.85158976,  0.93694356, ..., -0.01419548,
#          0.88061618,  0.48458345],
#        [-0.20576781,  0.14550526,  0.86413904, ..., -0.30806423,
#         -1.42223899, -0.48334339],
#        [ 0.52201905, -1.66958897,  0.26799534, ...,  0.47444746,
#          0.06377656,  0.35359602],
#        ...,
#        [ 0.12473432,  0.24218002, -0.31360389, ..., -0.06709297,
#         -0.45158337, -0.72599831],
#        [-0.36520641, -0.07025697, -0.96940967, ..., -1.30078611,
#         -1.37707964, -0.74127321],
#        [ 0.80789993,  1.07926291,  0.055495  , ...,  0.2481593 ,
#          0.76037441,  0.63576928]])

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm = confusion_matrix(y_pred, Y_test)
print(cm)
print(accuracy_score(y_pred,Y_test))
classification_report(y_pred, Y_test)
# Out:
# [[0 0 0]
#  [0 1 0]
#  [2 3 9]]
# 0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# '              precision    recall  f1-score   support\n\n           1       0.00      0.00      0.00         0\n           2       0.25      1.00      0.40         1\n           3       1.00      0.64      0.78        14\n\n    accuracy                           0.67        15\n   macro avg       0.42      0.55      0.39        15\nweighted avg       0.95      0.67      0.76        15\n'

# %%
from sklearn.linear_model import LogisticRegression
lg_classifier = LogisticRegression(random_state=0)
lg_classifier.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
